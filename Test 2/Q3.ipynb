# %% [markdown]
# ![alt text](Q3.png)

# %%
# Out:
# y[n] = ax[n] +(1-a)y[n-1]
# Whereby a = 0.02, x[n]=n

# %%
yn=0
print('y[n] = ax[n] +(1-a)y[n-1]\nWhereby a = 0.02, x[n]=n')
for i in range(0, 44):
    y = 0.02*i +(1-0.02)*yn
    yn = y
    print(f'y[{i}] = {y}')
    print(y)
# Out:
# y[n] = ax[n] +(1-a)y[n-1]
# Whereby a = 0.02, x[n]=n
# y[0] = 0.0
# 0.0
# y[1] = 0.02
# 0.02
# y[2] = 0.0596
# 0.0596
# y[3] = 0.118408
# 0.118408
# y[4] = 0.19603984
# 0.19603984
# y[5] = 0.2921190432
# 0.2921190432
# y[6] = 0.40627666233599996
# 0.40627666233599996
# y[7] = 0.53815112908928
# 0.53815112908928
# y[8] = 0.6873881065074944
# 0.6873881065074944
# y[9] = 0.8536403443773444
# 0.8536403443773444
# y[10] = 1.0365675374897976
# 1.0365675374897976
# y[11] = 1.2358361867400016
# 1.2358361867400016
# y[12] = 1.4511194630052016
# 1.4511194630052016
# y[13] = 1.6820970737450975
# 1.6820970737450975
# y[14] = 1.9284551322701955
# 1.9284551322701955
# y[15] = 2.1898860296247915
# 2.1898860296247915
# y[16] = 2.4660883090322954
# 2.4660883090322954
# y[17] = 2.7567665428516492
# 2.7567665428516492
# y[18] = 3.0616312119946163
# 3.0616312119946163
# y[19] = 3.380398587754724
# 3.380398587754724
# y[20] = 3.7127906159996296
# 3.7127906159996296
# y[21] = 4.058534803679637
# ...

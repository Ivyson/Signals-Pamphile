# %% [markdown]
# ![alt text](./Images/Q9.png)

# %% [markdown]
# # Finding the relationship
# To understand what this question is looking for, You are required to find the relationship between $x_1 \text{and} x_2$, and apply that relationship between $y_1 \text{and} y_2$
#
# This implies that, if $x_2  = n \times x_1$
# then $y_2 = n \times y_1$
#
# Same principle applies for time reversal cases whereby the equations are the same, just the other is time shifted. The below example uses both cases, amplitude scaling and time reversal

# %%
import sympy as sm
t = sm.symbols('t')
u = sm.Heaviside
y1 = t*u(t)-(t-3)*u(t-3)-(t-5)*u(t-5)+(t-8)*u(t-8)
x1 =2*u(t)-u(t-3)-u(t-5)
x2 = 4*u(t-3)-2*u(t-6)-2*u(t-8)

"""
x2 = 2*u(t-3)
: y2 = 2y1(t-3)
"""
y2 = 2*y1.subs(t, t-3)
y2.subs(t, 6)
# Out:
# 6

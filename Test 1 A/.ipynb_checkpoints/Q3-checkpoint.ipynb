# %% [markdown]
# ![alt text](./Images/Q3.png)

# %% [markdown]
# > Finding the even components of the dsicrete function:
#
#
# $x_\text{even} = \frac{1}{2} (x[t] + x[-t])$

# %%
import numpy as np
# Create the n axis -> Discrete time stamps
n = np.arange(-7, 8)
# Create the corresponding y values
x = np.array([0, 0, 0, -1, -1, -1, 0, 1, 2, 3, 3, 1, 1, 0, 0])
xeven = 0.5 * (x + x[::-1])  # The x[::-1] -> Does a time reversal
# # The sums that we want
values = np.where((n >= -2) & (n <= 5))
sum_even = xeven[values].sum()
print(f'The sum is : {sum_even}')
# Out:
# The sum is : 6.5
